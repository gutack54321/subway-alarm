# %%
import requests as rq
from bs4 import BeautifulSoup
from urllib.request import urlretrieve
from urllib.parse import urljoin
from IPython.display import Image
import json
import pandas as pd
import pprint
from pandas.io.json import json_normalize
from datetime import timedelta
import re

# %%
api_code_1= "6b4450457667757439365457477973"       #input("api인증키 : ")     #도착api 인증키 입력 #6b4450457667757439365457477973

api_code='584c666a6e67757436385270714c65'                #input("api인증키 : ")     #시간api 인증키 입력 #  584c666a6e67757436385270714c65

# %%
#출발역 도착역 출발시간 요일 상하행선 입력 후 url 작성코드

sw_start_s= input("출발역 : ") 
sw_end_s= input("도착역 : ") 
a = input('몇시(00시부터24시):')
b = input('몇분:')
print(f'출발시간 : {a}:{b} 입니다.')

sw_start_time_1=a+b+"00"
sw_start_time=int(sw_start_time_1)
print(sw_start_time)


print("1. 평일")
print("2. 토요일")
print("3. 공휴일/일요일")

inputed_number = int(input("번호를 입력하세요(day_num) : "))

if inputed_number == 1:
    day_num=str(inputed_number)
elif inputed_number ==2:
    day_num=str(inputed_number)
elif inputed_number ==3:
    day_num=str(inputed_number)
else:
    print('다시 입력하세요')


print("1. 상행선/내부")
print("2. 하행선/외부")


inputed_number1 = int(input("번호를 입력하세요(inout_num) : "))

if inputed_number == 1:
    inout_num=str(inputed_number)
elif inputed_number ==2:
    inout_num=str(inputed_number)
else:
    print('다시 입력하세요')

csv_code = pd.read_csv('C:/Users/Administrator/Desktop/subway/code.csv')


for row_index, row in csv_code.iterrows():
    if row.station_name == sw_start_s:
        
        sw_start_s_code = str(row.station_code)
        print(f'전철역코드(sw_start_s_code): {sw_start_s_code}')
        
        sw_line_num = row.line_num
        print(f'호선(sw_line_num): {sw_line_num}')
        
        break
    
    
#     print(row_index)
#     print(row)

url="http://openAPI.seoul.go.kr:8088/"+api_code+"/xml/SearchSTNTimeTableByIDService/1/500/"+sw_start_s_code+'/'+day_num+'/'+inout_num+"/"
res = rq.get(url)
soup = BeautifulSoup(res.text, 'html')
# print(soup.prettify())
# print(soup.find_all('arrivetime'))
#sw_start_time 입력한 출발시간

url_1="http://swopenAPI.seoul.go.kr/api/subway/"+api_code_1+"/xml/realtimeStationArrival/0/500/"+sw_end_s
#도착api url코드
res_1 = rq.get(url_1)
soup1 = BeautifulSoup(res_1.text, 'html')
# print(soup1.prettify())

url_2="http://swopenAPI.seoul.go.kr/api/subway/"+api_code_1+"/xml/realtimeStationArrival/0/500/"+sw_start_s
#도착api url코드
res_2 = rq.get(url_2)
soup2 = BeautifulSoup(res_2.text, 'html')

ar_time= soup.find_all('arrivetime') #arrivetime태그 전부
time_min=sw_start_time-500
time_max=sw_start_time+500

time_min1=sw_start_time-1000
time_max1=sw_start_time+1000

time_min2=sw_start_time-2000
time_max2=sw_start_time+2000

time_min3=sw_start_time-3000
time_max3=sw_start_time+3000

time_min4=sw_start_time-4000
time_max4=sw_start_time+4000

time_min_str = str(time_min)
time_min_int = int(time_min_str[2])
if time_min_int >= 6:
    time_min = time_min + 4000
    
time_min_str1 = str(time_min1)
time_min_int1 = int(time_min_str1[2])
if time_min_int1 >= 6:
    time_min1 = time_min1 + 4000

time_min_str2 = str(time_min2)
time_min_int2 = int(time_min_str2[2])
if time_min_int2 >= 6:
    time_min2 = time_min2 + 4000

time_min_str3 = str(time_min3)
time_min_int3 = int(time_min_str3[2])
if time_min_int3 >= 6:
    time_min3 = time_min3 + 4000
    
time_min_str4 = str(time_min4)
time_min_int4 = int(time_min_str4[2])
if time_min_int4 >= 6:
    time_min4 = time_min4 + 4000


time_max_str = str(time_max)
time_max_int = int(time_max_str[2])
if time_max_int >= 6:
    time_max = time_max + 4000
    
time_max_str1 = str(time_max1)
time_max_int1 = int(time_max_str1[2])
if time_max_int1 >= 6:
    time_max1 = time_max1 + 4000

time_max_str2 = str(time_max2)
time_max_int2 = int(time_max_str2[2])
if time_max_int2 >= 6:
    time_max2 = time_max2 + 4000

time_max_str3 = str(time_max3)
time_max_int3 = int(time_max_str3[2])
if time_max_int3 >= 6:
    time_max3 = time_max3 + 4000
    
time_max_str4 = str(time_max4)
time_max_int4 = int(time_max_str4[2])
if time_max_int4 >= 6:
    time_max4 = time_max4 + 4000    
    
    
    
ar_time_list_500=[]
ar_time_list_1000=[]
ar_time_list_2000=[]
ar_time_list_3000=[]
ar_time_list_4000=[]

for i in ar_time:
    ar_time_txt=i.text             # 출발시간
    ar_time_txt_1= i.text.replace( ":","")
    ar_time_num= int(ar_time_txt_1)

    
 
    
#   for문안에서 시간분류코드
    if time_min < ar_time_num < time_max:
        ar_time_list_500.append(ar_time_num)
        
        
    elif time_min1 < ar_time_num < time_max1:
        ar_time_list_1000.append(ar_time_num)
                                                            
        
    elif time_min2 < ar_time_num < time_max2:
        ar_time_list_2000.append(ar_time_num)
        
        
    elif time_min3 < ar_time_num < time_max3:
        ar_time_list_3000.append(ar_time_num)
        
        
    elif time_min4 < ar_time_num < time_max4:
        ar_time_list_4000.append(ar_time_num)
        

all_time_list = ar_time_list_500 + ar_time_list_1000 + ar_time_list_2000 + ar_time_list_3000 + ar_time_list_4000
all_time_list.sort()
all_time_list

all_list = []


for i in all_time_list:
    i = str(i)
    if len(i) == 5:
        i = '0' + i
    else :
        i = i 
    if len(i) ==6:
        i = i[:2] + ':' +i[2:4] + ':' + i[4:]
        all_list.append(i)

       
print(all_list)

# print(f'5분이내 :ar_time_list_500 {ar_time_list_500}')        
# print(f'10분이내 :ar_time_list_1000 {ar_time_list_1000}')        
# print(f'20분이내 :ar_time_list_20000 {ar_time_list_2000}')        
# print(f'30분이내 :ar_time_list_3000 {ar_time_list_3000}')        
# print(f'40분이내 :ar_time_list_4000 {ar_time_list_4000}')

#입력시간에서 가까운 시간표 리스트로 나누어 저장
# Out:
# 출발역 : 수원
# 도착역 : 수원
# 몇시(00시부터24시):14
# 몇분:44
# 출발시간 : 14:44 입니다.
# 144400
# 1. 평일
# 2. 토요일
# 3. 공휴일/일요일
# 번호를 입력하세요(day_num) : 1
# 1. 상행선/내부
# 2. 하행선/외부
# 번호를 입력하세요(inout_num) : 1
# 전철역코드(sw_start_s_code): 1713
# 호선(sw_line_num): 1
# ['14:05:30', '14:14:30', '14:23:00', '14:28:30', '14:38:30', '14:47:00', '14:51:30', '15:01:30', '15:10:00', '15:20:30']

# %%
all_list_index = int(input("번호를 입력하세요(all_list_index) : "))
all_list_index= all_list_index-1
# Out:
# 번호를 입력하세요(all_list_index) : 7

# %%
str_second1= all_list[all_list_index]

#str_second1(입력시간중 가장가까운시간)의 열차코드

url_1="http://swopenAPI.seoul.go.kr/api/subway/"+api_code_1+"/xml/realtimeStationArrival/0/500/"+sw_end_s
#도착api url코드
res_1 = rq.get(url_1)
soup1 = BeautifulSoup(res_1.text, 'html')
# print(soup1.prettify())



for i in ar_time:
    ar_time_txt=i.text 
    if str_second1 == ar_time_txt:
        tag_par=i.parent
        train_num = tag_par.train_no.text
        train_num= re.sub('[^0-9]','', train_num)
        train_num=int(train_num)


btrain_no = soup1.find_all('btrainno') #도착api에서 열차번호
btrain_n = soup1.find_all('arvlmsg2')


# print(str_second1)
# print(train_num)
# print(btrain_no,'btrain_no')

# print(btrain_n,'MSG')
# print(url_1)
for i in btrain_no:           
    btrain_no_txt = i.text 
    btrain_no_txt= re.sub('[^0-9]','', btrain_no_txt)
    btrain_no_txt=int(btrain_no_txt)
#     print(btrain_no_txt,"btrain_no_txt")
    arvlmsg2_txt = i.parent.arvlmsg2.text  
    if train_num == btrain_no_txt and "전역" in arvlmsg2_txt:       
        print('전역입니다.일어나세요')
            
    elif train_num == btrain_no_txt and sw_end_s in arvlmsg2_txt:    
        print(f'{sw_end_s}입니다.일어나세요 제발')
# Out:
# 수원입니다.일어나세요 제발

# %%
str_second1= all_list[all_list_index]

url_2="http://swopenAPI.seoul.go.kr/api/subway/"+api_code_1+"/xml/realtimeStationArrival/0/500/"+sw_start_s
#도착api url코드
res_2 = rq.get(url_2)
soup2 = BeautifulSoup(res_2.text, 'html')

for i in ar_time:
    ar_time_txt=i.text 
    if str_second1 == ar_time_txt:
        tag_par=i.parent
        train_num = tag_par.train_no.text
        train_num= re.sub('[^0-9]','', train_num)
        train_num=int(train_num)


btrain_no = soup2.find_all('btrainno') #도착api에서 열차번호
btrain_n = soup2.find_all('arvlmsg2')


# print(btrain_no,'btrain_no')

# print(btrain_n,'MSG')
# print(url_1)
for i in btrain_no:           
    btrain_no_txt = i.text 
    btrain_no_txt= re.sub('[^0-9]','', btrain_no_txt)
    btrain_no_txt=int(btrain_no_txt)
#     print(btrain_no_txt,"btrain_no_txt")
    arvlmsg2_txt = i.parent.arvlmsg2.text  
    if train_num == btrain_no_txt and "전역" in arvlmsg2_txt:       
        print('전역입니다.일어나세요')
            
    elif train_num == btrain_no_txt and sw_start_s in arvlmsg2_txt:    
        print(f'{sw_start_s}입니다.일어나세요 제발')
# Out:
# 수원입니다.일어나세요 제발
